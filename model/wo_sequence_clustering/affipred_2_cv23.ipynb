# %%
import matplotlib.pyplot as plt
import seaborn as sns
import os
import numpy as np
import pandas as pd
import random
import math
# from operator import itemgetter
from sklearn import metrics
from sklearn.metrics import roc_auc_score, make_scorer, log_loss
from sklearn.model_selection import cross_val_score, StratifiedKFold, KFold
from sklearn.utils import compute_class_weight
import xgboost as xgb
from xgboost import XGBClassifier
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope
from functools import partial
import warnings
warnings.filterwarnings('ignore')

# %%
path2data = 'D:\\__PROJECTS\\__AFbPP\\April2023\\affipred_models\\'
os.chdir(path2data)

# split train and blind set 
NUMBER = 2
path2res = 'D:\\__PROJECTS\\__AFbPP\\April2023\\affipred_models\\fold'+str(NUMBER)+'\\'

target = 'two_states'
features = ['GO_number','plddt_mean',
            'kdHydrophobicity_DELTAmn', 'Volume_(A3)_n', 'plddt', 'ASA',
            'b62', 'wt_psic', 'mt_psic', 'dpsic']

## read data
train = pd.read_csv("TRAIN"+ str(NUMBER) +"_CV0423.csv", sep=';')

X = train[features]
y = train[target]

X = X.to_numpy()
y= y.to_numpy()

# %%
evals = 200
inner_f = 5
outer_f = 10
RND = 1

# %%
savename = "Fold"+ str(NUMBER) + "_" + str(evals) + "evals_nestcv_" + str(outer_f) + "_" + str(inner_f) + "_" + str(RND)

# %% [markdown]
# ### Nested CV

# %%
# Hyperparameter space
space = {
    'objective': 'binary:logistic',
    'n_estimators': hp.choice('n_estimators', range(500, 2000)),
    'learning_rate': hp.loguniform('learning_rate', -5, 0),
    'max_depth': hp.choice('max_depth', range(3, 10)),
    'min_child_weight': hp.loguniform('min_child_weight', -5, 5),
    'subsample': hp.uniform('subsample', 0.5, 1),
    'colsample_bytree': hp.uniform('colsample_bytree', 0.5, 1),
    'gamma': hp.uniform('gamma', 0.05, 10),
    'reg_alpha': hp.uniform('reg_alpha', 0, 1),
    'reg_lambda': hp.uniform('reg_lambda', 0.01,1)
}

# %%
# Create a list to store results of each evaluation step
evaluation_results = []

# Objective function for hyperopt optimization
def objective(params, X, y, cv):
    model = xgb.XGBClassifier(**params, use_label_encoder=False, eval_metric='auc')
    scores = cross_val_score(model, X, y, cv=cv, scoring='roc_auc')
    avg_score = np.average(scores)
    result = {'loss': -avg_score, 'status': STATUS_OK, 'params': params}
    evaluation_results.append(result) 
    return result

def nested_cv(X, y, cv_outer, cv_inner, space):
    outer_scores = []
    logloss_scores =[]
    best_score = None

    for i, (train_idx, val_idx) in enumerate(cv_outer.split(X, y)):
        X_train, y_train = X[train_idx], y[train_idx]
        X_val, y_val = X[val_idx], y[val_idx]

        inner_scores = []
        logloss =[]

        for j, (train_idx_inner, val_idx_inner) in enumerate(cv_inner.split(X_train, y_train)):
            X_train_inner, y_train_inner = X_train[train_idx_inner], y_train[train_idx_inner]
            X_val_inner, y_val_inner = X_train[val_idx_inner], y_train[val_idx_inner]

            print("outer fold:", i,"inner fold:", j)
            print("size of training, validation in outer: ", len(X_train), len(X_val))
            print("size of training, validation in inner: ", len(X_train_inner), len(X_val_inner))

            # Hyperparameter in the inner cross-validation
            obj_func = partial(objective, X=X_train_inner, y=y_train_inner, cv=cv_inner)
            result = fmin(fn=obj_func, space=space, algo=tpe.suggest, max_evals=evals,
                          rstate=np.random.default_rng(RND))

            # Fit model with best hyperparameters on entire training set
            params = {**space, **result}
            model = xgb.XGBClassifier(**params, use_label_encoder=False,eval_metric='auc')
            model.fit(X_train, y_train)

            # Evaluate model on outer validation set
            score = model.score(X_val, y_val)
            inner_scores.append(score)

            if best_score is None or score > best_score:
                best_score = score
                best_train_indices = train_idx
                best_test_indices = val_idx
                best_model = str(i)+"_"+str(j)

            # Compute log loss on train and test sets
            y_train_pred = model.predict_proba(X_train)
            y_val_pred = model.predict_proba(X_val)
            train_loss = log_loss(y_train, y_train_pred)
            val_loss = log_loss(y_val, y_val_pred)
            logloss.append((train_loss, val_loss))

        logloss_scores.append(logloss)
        outer_scores.append(inner_scores)

    return params, outer_scores, logloss_scores, best_train_indices, best_test_indices, best_score, best_model

# Define outer and inner cross-validation folds
cv_outer = StratifiedKFold(n_splits=outer_f, shuffle=True, random_state=RND)
cv_inner = StratifiedKFold(n_splits=inner_f, shuffle=True, random_state=RND)

try:
    # Perform nested cross-validation with
    best_params, scores, logloss, \
    train_index_list, test_index_list, \
    best_score, best_model = nested_cv(X, y, cv_outer, cv_inner, space)
    print("Best hyperparameters:", best_params)
    print("AUC from nested cross-validation:")
    for i, outer_fold_scores in enumerate(scores):
        print(f"Outer Fold {i+1}: {outer_fold_scores}")

except Exception as e:
    print("Error: ", e)
# Out:
# outer fold: 0 inner fold: 0
# size of training, validation in outer:  44478 4943
# size of training, validation in inner:  35582 8896
# 100%|█████████████████████████████████████████████| 200/200 [32:40<00:00,  9.80s/trial, best loss: -0.9533346800904257]
# outer fold: 0 inner fold: 1
# size of training, validation in outer:  44478 4943
# size of training, validation in inner:  35582 8896
# 100%|█████████████████████████████████████████████| 200/200 [30:58<00:00,  9.29s/trial, best loss: -0.9532769601554557]
# outer fold: 0 inner fold: 2
# size of training, validation in outer:  44478 4943
# size of training, validation in inner:  35582 8896
# 100%|█████████████████████████████████████████████| 200/200 [34:59<00:00, 10.50s/trial, best loss: -0.9527334896734176]
# outer fold: 0 inner fold: 3
# size of training, validation in outer:  44478 4943
# size of training, validation in inner:  35583 8895
# 100%|█████████████████████████████████████████████| 200/200 [31:38<00:00,  9.49s/trial, best loss: -0.9525008848003805]
# outer fold: 0 inner fold: 4
# size of training, validation in outer:  44478 4943
# size of training, validation in inner:  35583 8895
# 100%|█████████████████████████████████████████████| 200/200 [33:50<00:00, 10.15s/trial, best loss: -0.9536118506520139]
# outer fold: 1 inner fold: 0
# size of training, validation in outer:  44479 4942
# size of training, validation in inner:  35583 8896
# 100%|█████████████████████████████████████████████| 200/200 [29:39<00:00,  8.90s/trial, best loss: -0.9527523302674101]
# outer fold: 1 inner fold: 1
# size of training, validation in outer:  44479 4942
# size of training, validation in inner:  35583 8896
# 100%|██████████████████████████████████████████████| 200/200 [32:36<00:00,  9.78s/trial, best loss: -0.953284040532276]
# outer fold: 1 inner fold: 2
# size of training, validation in outer:  44479 4942
# size of training, validation in inner:  35583 8896
# 100%|█████████████████████████████████████████████| 200/200 [29:58<00:00,  8.99s/trial, best loss: -0.9523970630970016]
# outer fold: 1 inner fold: 3
# size of training, validation in outer:  44479 4942
# size of training, validation in inner:  35583 8896
# 100%|█████████████████████████████████████████████| 200/200 [29:59<00:00,  9.00s/trial, best loss: -0.9517976434071205]
# outer fold: 1 inner fold: 4
# size of training, validation in outer:  44479 4942
# size of training, validation in inner:  35584 8895
# 100%|█████████████████████████████████████████████| 200/200 [28:50<00:00,  8.65s/trial, best loss: -0.9528862539745029]
# outer fold: 2 inner fold: 0
# size of training, validation in outer:  44479 4942
# size of training, validation in inner:  35583 8896
# 100%|█████████████████████████████████████████████| 200/200 [32:11<00:00,  9.66s/trial, best loss: -0.9525339004708968]
# outer fold: 2 inner fold: 1
# size of training, validation in outer:  44479 4942
# size of training, validation in inner:  35583 8896
# 100%|█████████████████████████████████████████████| 200/200 [30:34<00:00,  9.17s/trial, best loss: -0.9523672426536709]
# outer fold: 2 inner fold: 2
# size of training, validation in outer:  44479 4942
# size of training, validation in inner:  35583 8896
# 100%|█████████████████████████████████████████████| 200/200 [33:03<00:00,  9.92s/trial, best loss: -0.9526930749208342]
# outer fold: 2 inner fold: 3
# size of training, validation in outer:  44479 4942
# size of training, validation in inner:  35583 8896
# 100%|█████████████████████████████████████████████| 200/200 [35:34<00:00, 10.67s/trial, best loss: -0.9524856806344075]
# outer fold: 2 inner fold: 4
# size of training, validation in outer:  44479 4942
# size of training, validation in inner:  35584 8895
# 100%|█████████████████████████████████████████████| 200/200 [38:42<00:00, 11.61s/trial, best loss: -0.9522368432807585]
# outer fold: 3 inner fold: 0
# size of training, validation in outer:  44479 4942
# size of training, validation in inner:  35583 8896
# 100%|█████████████████████████████████████████████| 200/200 [34:29<00:00, 10.35s/trial, best loss: -0.9540696320271914]
# outer fold: 3 inner fold: 1
# size of training, validation in outer:  44479 4942
# size of training, validation in inner:  35583 8896
# 100%|█████████████████████████████████████████████| 200/200 [30:42<00:00,  9.21s/trial, best loss: -0.9540155820378337]
# outer fold: 3 inner fold: 2
# size of training, validation in outer:  44479 4942
# size of training, validation in inner:  35583 8896
# 100%|█████████████████████████████████████████████| 200/200 [35:26<00:00, 10.63s/trial, best loss: -0.9537608442532693]
# outer fold: 3 inner fold: 3
# size of training, validation in outer:  44479 4942
# size of training, validation in inner:  35583 8896
# 100%|█████████████████████████████████████████████| 200/200 [31:43<00:00,  9.52s/trial, best loss: -0.9531962895089556]
# outer fold: 3 inner fold: 4
# size of training, validation in outer:  44479 4942
# size of training, validation in inner:  35584 8895
# 100%|█████████████████████████████████████████████| 200/200 [33:40<00:00, 10.10s/trial, best loss: -0.9534604589973477]
# outer fold: 4 inner fold: 0
# size of training, validation in outer:  44479 4942
# size of training, validation in inner:  35583 8896
# 100%|█████████████████████████████████████████████| 200/200 [29:14<00:00,  8.77s/trial, best loss: -0.9530557325832831]
# outer fold: 4 inner fold: 1
# size of training, validation in outer:  44479 4942
# size of training, validation in inner:  35583 8896
# 100%|█████████████████████████████████████████████| 200/200 [30:19<00:00,  9.10s/trial, best loss: -0.9520383070921825]
# outer fold: 4 inner fold: 2
# size of training, validation in outer:  44479 4942
# size of training, validation in inner:  35583 8896
# 100%|█████████████████████████████████████████████| 200/200 [32:29<00:00,  9.75s/trial, best loss: -0.9540595880098804]
# outer fold: 4 inner fold: 3
# size of training, validation in outer:  44479 4942
# size of training, validation in inner:  35583 8896
# 100%|█████████████████████████████████████████████| 200/200 [35:16<00:00, 10.58s/trial, best loss: -0.9530702630206376]
# outer fold: 4 inner fold: 4
# size of training, validation in outer:  44479 4942
# size of training, validation in inner:  35584 8895
# 100%|█████████████████████████████████████████████| 200/200 [31:50<00:00,  9.55s/trial, best loss: -0.9528657822072664]
# outer fold: 5 inner fold: 0
# size of training, validation in outer:  44479 4942
# size of training, validation in inner:  35583 8896
# 100%|█████████████████████████████████████████████| 200/200 [35:19<00:00, 10.60s/trial, best loss: -0.9534822529167499]
# outer fold: 5 inner fold: 1
# size of training, validation in outer:  44479 4942
# size of training, validation in inner:  35583 8896
# 100%|█████████████████████████████████████████████| 200/200 [26:58<00:00,  8.09s/trial, best loss: -0.9524962841421534]
# outer fold: 5 inner fold: 2
# size of training, validation in outer:  44479 4942
# size of training, validation in inner:  35583 8896
# 100%|█████████████████████████████████████████████| 200/200 [36:39<00:00, 11.00s/trial, best loss: -0.9532542676351035]
# outer fold: 5 inner fold: 3
# size of training, validation in outer:  44479 4942
# size of training, validation in inner:  35583 8896
# 100%|█████████████████████████████████████████████| 200/200 [34:18<00:00, 10.29s/trial, best loss: -0.9529933861497624]
# outer fold: 5 inner fold: 4
# size of training, validation in outer:  44479 4942
# size of training, validation in inner:  35584 8895
# 100%|█████████████████████████████████████████████| 200/200 [31:32<00:00,  9.46s/trial, best loss: -0.9535316061507612]
# outer fold: 6 inner fold: 0
# size of training, validation in outer:  44479 4942
# size of training, validation in inner:  35583 8896
# 100%|█████████████████████████████████████████████| 200/200 [30:21<00:00,  9.11s/trial, best loss: -0.9523488831534124]
# outer fold: 6 inner fold: 1
# size of training, validation in outer:  44479 4942
# size of training, validation in inner:  35583 8896
# 100%|█████████████████████████████████████████████| 200/200 [32:41<00:00,  9.81s/trial, best loss: -0.9521794927629479]
# outer fold: 6 inner fold: 2
# size of training, validation in outer:  44479 4942
# size of training, validation in inner:  35583 8896
# 100%|█████████████████████████████████████████████| 200/200 [32:09<00:00,  9.65s/trial, best loss: -0.9535472555702207]
# outer fold: 6 inner fold: 3
# size of training, validation in outer:  44479 4942
# size of training, validation in inner:  35583 8896
# 100%|█████████████████████████████████████████████| 200/200 [35:21<00:00, 10.61s/trial, best loss: -0.9526686149681195]
# outer fold: 6 inner fold: 4
# size of training, validation in outer:  44479 4942
# size of training, validation in inner:  35584 8895
# 100%|█████████████████████████████████████████████| 200/200 [32:52<00:00,  9.86s/trial, best loss: -0.9535382524811571]
# outer fold: 7 inner fold: 0
# size of training, validation in outer:  44479 4942
# size of training, validation in inner:  35583 8896
# 100%|█████████████████████████████████████████████| 200/200 [33:17<00:00,  9.99s/trial, best loss: -0.9527962634664844]
# outer fold: 7 inner fold: 1
# size of training, validation in outer:  44479 4942
# size of training, validation in inner:  35583 8896
# 100%|█████████████████████████████████████████████| 200/200 [33:19<00:00, 10.00s/trial, best loss: -0.9529077566888795]
# outer fold: 7 inner fold: 2
# size of training, validation in outer:  44479 4942
# size of training, validation in inner:  35583 8896
# 100%|█████████████████████████████████████████████| 200/200 [33:30<00:00, 10.05s/trial, best loss: -0.9523551099134808]
# outer fold: 7 inner fold: 3
# size of training, validation in outer:  44479 4942
# size of training, validation in inner:  35583 8896
# 100%|██████████████████████████████████████████████| 200/200 [28:52<00:00,  8.66s/trial, best loss: -0.952024253360435]
# outer fold: 7 inner fold: 4
# size of training, validation in outer:  44479 4942
# size of training, validation in inner:  35584 8895
# 100%|█████████████████████████████████████████████| 200/200 [34:21<00:00, 10.31s/trial, best loss: -0.9525382494558199]
# outer fold: 8 inner fold: 0
# size of training, validation in outer:  44479 4942
# size of training, validation in inner:  35583 8896
# 100%|█████████████████████████████████████████████| 200/200 [32:25<00:00,  9.73s/trial, best loss: -0.9535428090552373]
# outer fold: 8 inner fold: 1
# size of training, validation in outer:  44479 4942
# size of training, validation in inner:  35583 8896
# 100%|█████████████████████████████████████████████| 200/200 [29:45<00:00,  8.93s/trial, best loss: -0.9538273743238882]
# outer fold: 8 inner fold: 2
# size of training, validation in outer:  44479 4942
# size of training, validation in inner:  35583 8896
# 100%|█████████████████████████████████████████████| 200/200 [34:50<00:00, 10.45s/trial, best loss: -0.9528823735568686]
# outer fold: 8 inner fold: 3
# size of training, validation in outer:  44479 4942
# size of training, validation in inner:  35583 8896
# 100%|█████████████████████████████████████████████| 200/200 [32:36<00:00,  9.78s/trial, best loss: -0.9531794993205267]
# outer fold: 8 inner fold: 4
# size of training, validation in outer:  44479 4942
# size of training, validation in inner:  35584 8895
# 100%|█████████████████████████████████████████████| 200/200 [33:16<00:00,  9.98s/trial, best loss: -0.9518887013572069]
# outer fold: 9 inner fold: 0
# size of training, validation in outer:  44479 4942
# size of training, validation in inner:  35583 8896
# 100%|█████████████████████████████████████████████| 200/200 [34:06<00:00, 10.23s/trial, best loss: -0.9532216385589181]
# outer fold: 9 inner fold: 1
# size of training, validation in outer:  44479 4942
# size of training, validation in inner:  35583 8896
# 100%|█████████████████████████████████████████████| 200/200 [33:52<00:00, 10.16s/trial, best loss: -0.9519949653439006]
# outer fold: 9 inner fold: 2
# size of training, validation in outer:  44479 4942
# size of training, validation in inner:  35583 8896
# 100%|█████████████████████████████████████████████| 200/200 [30:41<00:00,  9.21s/trial, best loss: -0.9529050477611953]
# outer fold: 9 inner fold: 3
# size of training, validation in outer:  44479 4942
# size of training, validation in inner:  35583 8896
# 100%|█████████████████████████████████████████████| 200/200 [29:38<00:00,  8.89s/trial, best loss: -0.9518669969871472]
# outer fold: 9 inner fold: 4
# size of training, validation in outer:  44479 4942
# size of training, validation in inner:  35584 8895
# 100%|█████████████████████████████████████████████| 200/200 [33:13<00:00,  9.97s/trial, best loss: -0.9526745671340746]
# Best hyperparameters: {'objective': 'binary:logistic', 'n_estimators': 719, 'learning_rate': 0.10368164563854666, 'max_depth': 6, 'min_child_weight': 0.08032363292948651, 'subsample': 0.8615154593777182, 'colsample_bytree': 0.7425856863110464, 'gamma': 0.05395582434788711, 'reg_alpha': 0.021387201180665304, 'reg_lambda': 0.11252042278801022}
# AUC from nested cross-validation:
# Outer Fold 1: [0.887517701800526, 0.8925753590936678, 0.8907546024681368, 0.8733562613797289, 0.8836738822577382]
# Outer Fold 2: [0.8723188992310805, 0.8727235936867664, 0.5989477944152165, 0.8603804127883448, 0.8727235936867664]
# Outer Fold 3: [0.877175232699312, 0.8870902468636179, 0.8800080938891137, 0.886078510724403, 0.8909348441926346]
# Outer Fold 4: [0.8846620801295022, 0.8723188992310805, 0.8842573856738163, 0.8911371914204775, 0.8921489275596924]
# Outer Fold 5: [0.8846620801295022, 0.8779846216106839, 0.887494941319304, 0.8921489275596924, 0.8834479967624443]
# Outer Fold 6: [0.8808174828004857, 0.877579927154998, 0.8893160663698907, 0.887494941319304, 0.8826386078510724]
# Outer Fold 7: [0.8737353298259813, 0.8907324969647916, 0.886483205180089, 0.8743423715095103, 0.8929583164710644]
# Outer Fold 8: [0.8876972885471469, 0.8885066774585189, 0.8818292189397006, 0.8806151355726427, 0.8794010522055847]
# Outer Fold 9: [0.8753541076487252, 0.8739376770538244, 0.8781869688385269, 0.886887899635775, 0.8828409550789155]
# Outer Fold 10: [0.8931606636989073, 0.8830433023067584, 0.8919465803318495, 0.8917442331040065, 0.8982193443949817]

# %%
os.chdir(path2res)
res = pd.DataFrame(evaluation_results)
res.to_csv(str(savename)+"_XGB_hyperopt.csv",sep=";")

# %% [markdown]
# ### Assessment of AFbPP on Unseen Test Set

# %%
best_params={'objective': 'binary:logistic', 'n_estimators': 719, 'learning_rate': 0.10368164563854666, 'max_depth': 6, 'min_child_weight': 0.08032363292948651, 'subsample': 0.8615154593777182, 'colsample_bytree': 0.7425856863110464, 'gamma': 0.05395582434788711, 'reg_alpha': 0.021387201180665304, 'reg_lambda': 0.11252042278801022}

# %%
# #Fit model on the entire training set
X = train[features]
y = train[target]
xgbs = xgb.XGBClassifier(**best_params,use_label_encoder=False)
xgbs.fit(X, y)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.7425856863110464, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0.05395582434788711,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.10368164563854666,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=0.08032363292948651, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=719,
#               n_jobs=None, num_parallel_tree=None, random_state=None, ...)

# %%
os.chdir(path2data)
blind = pd.read_csv("BLIND"+ str(NUMBER) +"_CV0423.csv", sep=';')

# Predict unseen test set
X = blind[features]
y = blind[target]

known_prot = list(set(train["uniprot"]))
unknown_prot = list(set(blind["uniprot"]))
common = [i for i in known_prot if i in unknown_prot]
known = [i for i in known_prot if i not in common]
unknown = [i for i in unknown_prot if i not in common]

# print("\033[1m"+"Features:"+"\033[0m",features)
# print("\033[1m"+"Total "+"\033[0m" +"set:","\033[1m" + str(len(train)+len(blind)) + "\033[0m","variants from", "\033[1m" + str(len(prot_list)) + "\033[0m","proteins")
print("\033[1m"+"Training "+"\033[0m" +"set:","\033[1m" + str(len(train)) + "\033[0m","variants from", "\033[1m" + str(len(known)) + "\033[0m","proteins")
print("\033[1m"+"Held-out test "+"\033[0m" +"set:","\033[1m" + str(len(blind)) + "\033[0m","variants from", "\033[1m" + str(len(unknown)) + "\033[0m","proteins")
print("\033[1m"+"Common"+"\033[0m" +" proteins in train and blind sets:","\033[1m" + str(len(common)) + "\033[0m")

###################

y_pred = xgbs.predict(X)
y_prob = xgbs.predict_proba(X)[:,1]

blind["Affipred"+str(NUMBER)] = y_pred
blind["Affipred_prob"+str(NUMBER)] = y_prob

######################################################
#Evaluate models
from sklearn import metrics
def evaluation_analysis(true_label,predicted,predictor,dataset):
    eval_results = dict({"dataset" : dataset,
                         "predictor" : predictor,
                         "size" : len(true_label),
                         "f1" : metrics.f1_score(true_label, predicted, average='binary'),
                         "precision": metrics.precision_score(true_label, predicted),
                         "recall": metrics.recall_score(true_label, predicted),
                         "accuracy": metrics.accuracy_score(true_label, predicted),
                         "matthews_corr": metrics.matthews_corrcoef(true_label, predicted),
                         "confusion_matrix": metrics.confusion_matrix(true_label, predicted)
                        })
    return(eval_results)

def evaluation_analysis2(true_label,predicted_score,predictor,dataset):
    eval_results = dict({"dataset" : dataset,
                         "predictor" : predictor,
                         "size" : len(true_label),
                         "auc": metrics.roc_auc_score(true_label, predicted_score),
                         "log_loss": metrics.log_loss(true_label, predicted_score),
                        })
    return(eval_results)

########################################

# print(list(blind))
# blind.to_csv("pred_BLIND"+ str(NUMBER) +"_CV0423_affi.csv", sep=';')
# Out:
# Training set: 49421 variants from 4912 proteins
# Held-out test set: 25909 variants from 2456 proteins
# Common proteins in train and blind sets: 0

# %%
pred_list = ['SIFT_converted_rankscore', 'SIFT4G_converted_rankscore','Polyphen2_HDIV_rankscore', 'Polyphen2_HVAR_rankscore', 
           'LRT_converted_rankscore', 'MutationTaster_converted_rankscore', 'MutationAssessor_rankscore', 'FATHMM_converted_rankscore', 
           'PROVEAN_converted_rankscore', 'VEST4_rankscore','MetaSVM_rankscore','MetaLR_rankscore', 'MetaRNN_rankscore', 
           'M-CAP_rankscore','REVEL_rankscore','MutPred_rankscore', 'MVP_rankscore','MPC_rankscore', 'PrimateAI_rankscore', 
            'DEOGEN2_rankscore','BayesDel_addAF_rankscore','BayesDel_noAF_rankscore', 'ClinPred_rankscore', 'LIST-S2_rankscore', 
           'CADD_raw_rankscore', 'DANN_rankscore', 'fathmm-MKL_coding_rankscore','fathmm-XF_coding_rankscore', 'Eigen-raw_coding_rankscore', 
            'Eigen-PC-raw_coding_rankscore', 'GenoCanyon_rankscore', 'integrated_fitCons_rankscore', 'GERP++_RS_rankscore', 
            'phyloP100way_vertebrate_rankscore', 'phyloP30way_mammalian_rankscore','phastCons100way_vertebrate_rankscore', 
            'phastCons30way_mammalian_rankscore', 'SiPhy_29way_logOdds_rankscore', 'EVmutation_score', 'PolyPhen-2_score',
             'Affipred_prob2','two_states']

#########################################
df1 = blind
df2 = df1.loc[df1["training_info"]=="new"]

### Evaluate on all of the unseen test set
df = df1[pred_list]
perf = []
for p in pred_list:
    dx = df.loc[~df[p].isna()]
    dx[p] =pd.to_numeric(dx[p],downcast="integer")
    d1 = pd.DataFrame([evaluation_analysis2(dx["two_states"],dx[p], p,"all")])
    d2 = pd.DataFrame([evaluation_analysis2(dx["two_states"],dx['Affipred_prob2'], "Affipred",p)])
    d3 = pd.concat([d1,d2])
    perf.append(d3)

dfx = pd.concat(perf)
dfx = dfx.loc[dfx["predictor"]!="two_states"]
dfx1 = dfx

#####################################################

pred_list2=['two_states','Affipred_prob2','rhapsody_prob.']
df = df2[pred_list2]

dx = df.loc[~df["rhapsody_prob."].isna()]
d1 = pd.DataFrame([evaluation_analysis2(dx["two_states"],dx["Affipred_prob2"], "Affipred","rhapsody_prob.")])
d2 = pd.DataFrame([evaluation_analysis2(dx["two_states"],dx["rhapsody_prob."], "rhapsody_prob.","all")])

dfx = pd.concat([d1,d2])
dfx2 = pd.concat([dfx1,dfx])
pd.set_option('display.max_rows', None)

display(dfx2)

os.chdir(path2res)
dfx2.to_csv(str(savename)+"_unseen_auc_logloss.csv", sep=";")
# Out:
#                                 dataset                             predictor  \
# 0                                   all              SIFT_converted_rankscore
# 0              SIFT_converted_rankscore                              Affipred
# 0                                   all            SIFT4G_converted_rankscore
# 0            SIFT4G_converted_rankscore                              Affipred
# 0                                   all              Polyphen2_HDIV_rankscore
# 0              Polyphen2_HDIV_rankscore                              Affipred
# 0                                   all              Polyphen2_HVAR_rankscore
# 0              Polyphen2_HVAR_rankscore                              Affipred
# 0                                   all               LRT_converted_rankscore
# 0               LRT_converted_rankscore                              Affipred
# 0                                   all    MutationTaster_converted_rankscore
# 0    MutationTaster_converted_rankscore                              Affipred
# 0                                   all            MutationAssessor_rankscore
# 0            MutationAssessor_rankscore                              Affipred
# 0                                   all            FATHMM_converted_rankscore
# 0            FATHMM_converted_rankscore                              Affipred
# 0                                   all           PROVEAN_converted_rankscore
# 0           PROVEAN_converted_rankscore                              Affipred
# 0                                   all                       VEST4_rankscore
# 0                       VEST4_rankscore                              Affipred
# 0                                   all                     MetaSVM_rankscore
# 0                     MetaSVM_rankscore                              Affipred
# 0                                   all                      MetaLR_rankscore
# 0                      MetaLR_rankscore                              Affipred
# 0                                   all                     MetaRNN_rankscore
# 0                     MetaRNN_rankscore                              Affipred
# 0                                   all                       M-CAP_rankscore
# 0                       M-CAP_rankscore                              Affipred
# 0                                   all                       REVEL_rankscore
# 0                       REVEL_rankscore                              Affipred
# 0                                   all                     MutPred_rankscore
# 0                     MutPred_rankscore                              Affipred
# 0                                   all                         MVP_rankscore
# 0                         MVP_rankscore                              Affipred
# 0                                   all                         MPC_rankscore
# 0                         MPC_rankscore                              Affipred
# 0                                   all                   PrimateAI_rankscore
# 0                   PrimateAI_rankscore                              Affipred
# 0                                   all                     DEOGEN2_rankscore
# 0                     DEOGEN2_rankscore                              Affipred
# 0                                   all              BayesDel_addAF_rankscore
# 0              BayesDel_addAF_rankscore                              Affipred
# 0                                   all               BayesDel_noAF_rankscore
# 0               BayesDel_noAF_rankscore                              Affipred
# 0                                   all                    ClinPred_rankscore
# 0                    ClinPred_rankscore                              Affipred
# 0                                   all                     LIST-S2_rankscore
# 0                     LIST-S2_rankscore                              Affipred
# 0                                   all                    CADD_raw_rankscore
# 0                    CADD_raw_rankscore                              Affipred
# 0                                   all                        DANN_rankscore
# 0                        DANN_rankscore                              Affipred
# 0                                   all           fathmm-MKL_coding_rankscore
# 0           fathmm-MKL_coding_rankscore                              Affipred
# 0                                   all            fathmm-XF_coding_rankscore
# 0            fathmm-XF_coding_rankscore                              Affipred
# 0                                   all            Eigen-raw_coding_rankscore
# 0            Eigen-raw_coding_rankscore                              Affipred
# 0                                   all         Eigen-PC-raw_coding_rankscore
# 0         Eigen-PC-raw_coding_rankscore                              Affipred
# 0                                   all                  GenoCanyon_rankscore
# 0                  GenoCanyon_rankscore                              Affipred
# 0                                   all          integrated_fitCons_rankscore
# 0          integrated_fitCons_rankscore                              Affipred
# 0                                   all                   GERP++_RS_rankscore
# 0                   GERP++_RS_rankscore                              Affipred
# 0                                   all     phyloP100way_vertebrate_rankscore
# 0     phyloP100way_vertebrate_rankscore                              Affipred
# 0                                   all       phyloP30way_mammalian_rankscore
# 0       phyloP30way_mammalian_rankscore                              Affipred
# 0                                   all  phastCons100way_vertebrate_rankscore
# 0  phastCons100way_vertebrate_rankscore                              Affipred
# 0                                   all    phastCons30way_mammalian_rankscore
# 0    phastCons30way_mammalian_rankscore                              Affipred
# 0                                   all         SiPhy_29way_logOdds_rankscore
# 0         SiPhy_29way_logOdds_rankscore                              Affipred
# 0                                   all                      EVmutation_score
# 0                      EVmutation_score                              Affipred
# 0                                   all                      PolyPhen-2_score
# 0                      PolyPhen-2_score                              Affipred
# 0                                   all                        Affipred_prob2
# 0                        Affipred_prob2                              Affipred
# 0                            two_states                              Affipred
# 0                        rhapsody_prob.                              Affipred
# 0                                   all                        rhapsody_prob.
#
#     size       auc   log_loss
# 0  25263  0.872821   0.487276
# 0  25263  0.915926   0.384670
# 0  25328  0.867159   0.496381
# 0  25328  0.916449   0.384498
# 0  24092  0.844639   0.526300
# 0  24092  0.911090   0.395186
# 0  24092  0.874524   0.484317
# 0  24092  0.911090   0.395186
# 0  24145  0.826854   0.524718
# 0  24145  0.914528   0.392406
# 0  25769  0.849354   0.496091
# 0  25769  0.915564   0.387253
# 0  23515  0.874796   0.499716
# 0  23515  0.911888   0.392868
# 0  25175  0.815555   0.824171
# 0  25175  0.915791   0.385866
# 0  25409  0.890250   0.469491
# 0  25409  0.916010   0.384932
# 0  25777  0.950159   0.393898
# 0  25777  0.916011   0.385123
# 0  25809  0.918228   0.592122
# 0  25809  0.915728   0.386589
# 0  25809  0.915537   0.550262
# 0  25809  0.915728   0.386589
# 0  25883  0.988489   0.149357
# 0  25883  0.915852   0.386244
# 0  19200  0.888767   0.616859
# 0  19200  0.908607   0.451273
# 0  25809  0.955483   0.482985
# 0  25809  0.915728   0.386589
# 0  12826  0.907046   0.336706
# 0  12826  0.906177   0.519239
# 0  23766  0.916011   0.661924
# 0  23766  0.912739   0.405798
# 0  23321  0.825448   0.555389
# 0  23321  0.915448   0.389154
# 0  25311  0.849416   0.515068
# 0  25311  0.916234   0.383884
# 0  24508  0.919712   0.616958
# 0  24508  0.911883   0.392506
# 0  25857  0.982297   0.196214
# 0  25857  0.915784   0.386535
# 0  25857  0.955683   0.408022
# 0  25857  0.915784   0.386535
# 0  25809  0.986813   0.174184
# 0  25809  0.915728   0.386589
# 0  24837  0.864321   0.559142
# 0  24837  0.916313   0.386384
# 0  25885  0.899038   0.444456
# 0  25885  0.915800   0.386398
# 0  25857  0.775196   0.857870
# 0  25857  0.915784   0.386535
# 0  25857  0.839395   0.555597
# 0  25857  0.915784   0.386535
# 0  23952  0.882632   0.531270
# 0  23952  0.915479   0.382637
# 0  23980  0.909265   0.433331
# 0  23980  0.915187   0.383294
# 0  23980  0.896357   0.457834
# 0  23980  0.915187   0.383294
# 0  25857  0.729400   0.667187
# 0  25857  0.915784   0.386535
# 0  24025  0.547616   0.909114
# 0  24025  0.915296   0.383091
# 0  25849  0.771828   0.639120
# 0  25849  0.915752   0.386646
# 0  25885  0.845093   0.563564
# 0  25885  0.915800   0.386398
# 0  25885  0.708236   0.666784
# 0  25885  0.915800   0.386398
# 0  25885  0.761982   0.564451
# 0  25885  0.915800   0.386398
# 0  25885  0.716475   0.644347
# 0  25885  0.915800   0.386398
# 0  25824  0.790712   0.653004
# 0  25824  0.915659   0.386923
# 0   8714  0.106485  25.616946
# 0   8714  0.891045   0.454770
# 0  25909  0.848381   2.923972
# 0  25909  0.915437   0.387206
# 0  25909  0.915437   0.387206
# 0  25909  0.915437   0.387206
# 0  25909  0.915437   0.387206
# 0   7888  0.865608   0.514889
# 0   7888  0.856382   0.481516

# %%
df = dfx2

preds =  ['SIFT_converted_rankscore', 'SIFT4G_converted_rankscore','Polyphen2_HDIV_rankscore', 'Polyphen2_HVAR_rankscore', 
         'LRT_converted_rankscore', 'MutationTaster_converted_rankscore', 'MutationAssessor_rankscore', 'FATHMM_converted_rankscore', 
         'PROVEAN_converted_rankscore', 'VEST4_rankscore','MetaSVM_rankscore','MetaLR_rankscore', 'MetaRNN_rankscore', 
         'M-CAP_rankscore','REVEL_rankscore','MutPred_rankscore', 'MVP_rankscore','MPC_rankscore', 'PrimateAI_rankscore', 
          'DEOGEN2_rankscore','BayesDel_addAF_rankscore','BayesDel_noAF_rankscore', 'ClinPred_rankscore', 'LIST-S2_rankscore', 
         'CADD_raw_rankscore', 'DANN_rankscore', 'fathmm-MKL_coding_rankscore','fathmm-XF_coding_rankscore', 'Eigen-raw_coding_rankscore', 
          'Eigen-PC-raw_coding_rankscore', 'GenoCanyon_rankscore', 'integrated_fitCons_rankscore', 'GERP++_RS_rankscore', 
          'phyloP100way_vertebrate_rankscore', 'phyloP30way_mammalian_rankscore','phastCons100way_vertebrate_rankscore', 
          'phastCons30way_mammalian_rankscore', 'SiPhy_29way_logOdds_rankscore','rhapsody_prob.', 'EVmutation_score', 'PolyPhen-2_score'
         ]
print(len(preds))
fig,ax = plt.subplots(1,41, figsize=(41,5),sharex=True,sharey=True)
plt.ylim(0,1)

for i, p in enumerate(preds):
    # print(i)
    dx = df.loc[(df["predictor"]==p)|(df["dataset"]==p)]
    dx=dx.sort_values("predictor",ascending=True)
    sns.barplot(ax = ax[i],data=dx, y ="auc", x="predictor",palette=["lightblue","lightgrey"])
    p = p.replace('_vertebrate_rankscore', '') 
    p = p.replace('_mammalian_rankscore', '') 
    p = p.replace('_converted_rankscore', '') 
    p = p.replace('_coding_rankscore', '')
    p = p.replace('_rankscore', '') 
    p = p.replace('_prob.', '') 
    p = p.replace('_score', '') 

    # p = p.replace('_vertebrate_rankscore', '') 
    # p = p.replace('_mammalian_rankscore', '') 
    # p = p.replace('_vertebrate_rankscore', '') 
    ax[i].set_title("AFFIPred\n"+str(p),rotation=90,fontsize=20,loc='left',x=0.1, y=0.01)
    ax[i].set_ylabel("",rotation=90,fontsize=20)
    ax[0].set_ylabel("AUROC",rotation=90,fontsize=20)
    ax[i].set_xlabel("",rotation=90,fontsize=20)
    ax[i].tick_params(labelsize=20)
    ax[i].spines['top'].set_visible(False)
    ax[i].spines['right'].set_visible(False)
    ax[i].spines['bottom'].set_visible(True)
    ax[i].spines['left'].set_visible(False)
    ax[0].spines['left'].set_visible(True)
    ax[40].spines['right'].set_visible(True)
    ax[i].set_xticks([])
    ax[i].set_yticks([0,0.5,1.0])
        
plt.savefig(str(savename)+"_blind_auc.png", dpi=300, facecolor='w', bbox_inches='tight', pad_inches=0.01)    
# plt.show()
# Out:
# 41

# %%
pred_list = ['SIFT_pred', 'SIFT4G_pred', 'Polyphen2_HDIV_pred', 'Polyphen2_HVAR_pred', 'LRT_pred', 'MutationTaster_pred', 
             'MutationAssessor_pred', 'FATHMM_pred', 'PROVEAN_pred', 'MetaSVM_pred', 'MetaLR_pred', 'MetaRNN_pred', 'M-CAP_pred', 
             'PrimateAI_pred', 'DEOGEN2_pred', 'BayesDel_addAF_pred', 'BayesDel_noAF_pred', 'ClinPred_pred', 'LIST-S2_pred', 
             'fathmm-MKL_coding_pred', 'fathmm-XF_coding_pred', 'EVmutation_two_states', 'PolyPhen-2_two_states', 'two_states', 
             'Affipred2']

#####################################################
df1 = blind
df2 = df1.loc[df1["training_info"]=="new"]

### Evaluate on all of the unseen test set
df = df1[pred_list]
perf = []
for p in pred_list:
    dx = df.loc[~df[p].isna()]
    dx[p] =pd.to_numeric(dx[p],downcast="integer")
    d1 = pd.DataFrame([evaluation_analysis(dx["two_states"],dx[p], p,"all")])
    d2 = pd.DataFrame([evaluation_analysis(dx["two_states"],dx['Affipred2'], "Affipred",p)])
    d3 = pd.concat([d1,d2])
    perf.append(d3)

dfx = pd.concat(perf)
dfx = dfx.loc[dfx["predictor"]!="two_states"]
dfx1 = dfx

#####################################################

pred_list2=['two_states','Affipred2','rhapsody_two_states']
df = df2[pred_list2]

dx = df.loc[~df["rhapsody_two_states"].isna()]
d1 = pd.DataFrame([evaluation_analysis(dx["two_states"],dx["Affipred2"], "Affipred","rhapsody_two_states")])
d2 = pd.DataFrame([evaluation_analysis(dx["two_states"],dx["rhapsody_two_states"], "rhapsody_two_states","all")])

dfx = pd.concat([d1,d2])

dfx2 = pd.concat([dfx1,dfx])
display(dfx2)

os.chdir(path2res)
dfx2.to_csv(str(savename)+"_unseen_f1_mcc_acc.csv", sep=";")
# Out:
#                   dataset               predictor   size        f1  precision  \
# 0                     all               SIFT_pred  25263  0.739940   0.620755
# 0               SIFT_pred                Affipred  25263  0.788138   0.836189
# 0                     all             SIFT4G_pred  25328  0.754515   0.670609
# 0             SIFT4G_pred                Affipred  25328  0.789743   0.837970
# 0                     all     Polyphen2_HDIV_pred  24092  0.715100   0.586254
# 0     Polyphen2_HDIV_pred                Affipred  24092  0.775422   0.827987
# 0                     all     Polyphen2_HVAR_pred  24092  0.750603   0.654989
# 0     Polyphen2_HVAR_pred                Affipred  24092  0.775422   0.827987
# 0                     all                LRT_pred  22802  0.750033   0.642614
# 0                LRT_pred                Affipred  22802  0.792976   0.840309
# 0                     all     MutationTaster_pred  24957  0.676702   0.518382
# 0     MutationTaster_pred                Affipred  24957  0.782421   0.827707
# 0                     all   MutationAssessor_pred  23515  0.734455   0.644287
# 0   MutationAssessor_pred                Affipred  23515  0.773409   0.829954
# 0                     all             FATHMM_pred  25175  0.686428   0.639495
# 0             FATHMM_pred                Affipred  25175  0.788826   0.836906
# 0                     all            PROVEAN_pred  25409  0.785762   0.716932
# 0            PROVEAN_pred                Affipred  25409  0.788595   0.836794
# 0                     all            MetaSVM_pred  25809  0.819940   0.807486
# 0            MetaSVM_pred                Affipred  25809  0.788414   0.837808
# 0                     all             MetaLR_pred  25809  0.798396   0.768554
# 0             MetaLR_pred                Affipred  25809  0.788414   0.837808
# 0                     all            MetaRNN_pred  25883  0.937601   0.924720
# 0            MetaRNN_pred                Affipred  25883  0.788357   0.838000
# 0                     all              M-CAP_pred  19200  0.781728   0.649624
# 0              M-CAP_pred                Affipred  19200  0.810922   0.889881
# 0                     all          PrimateAI_pred  25311  0.551905   0.805369
# 0          PrimateAI_pred                Affipred  25311  0.787349   0.837673
# 0                     all            DEOGEN2_pred  24508  0.796500   0.785656
# 0            DEOGEN2_pred                Affipred  24508  0.775155   0.828427
# 0                     all     BayesDel_addAF_pred  25857  0.918415   0.907014
# 0     BayesDel_addAF_pred                Affipred  25857  0.788373   0.837947
# 0                     all      BayesDel_noAF_pred  25857  0.861817   0.810226
# 0      BayesDel_noAF_pred                Affipred  25857  0.788373   0.837947
# 0                     all           ClinPred_pred  25809  0.935430   0.901205
# 0           ClinPred_pred                Affipred  25809  0.788414   0.837808
# 0                     all            LIST-S2_pred  24837  0.744221   0.638192
# 0            LIST-S2_pred                Affipred  24837  0.790198   0.841981
# 0                     all  fathmm-MKL_coding_pred  25857  0.686089   0.528712
# 0  fathmm-MKL_coding_pred                Affipred  25857  0.788373   0.837947
# 0                     all   fathmm-XF_coding_pred  23952  0.757159   0.648041
# 0   fathmm-XF_coding_pred                Affipred  23952  0.786436   0.831028
# 0                     all   EVmutation_two_states   8714  0.869246   0.891400
# 0   EVmutation_two_states                Affipred   8714  0.852398   0.912357
# 0                     all   PolyPhen-2_two_states  25909  0.727537   0.602116
# 0   PolyPhen-2_two_states                Affipred  25909  0.787711   0.836997
# 0              two_states                Affipred  25909  0.787711   0.836997
# 0                     all               Affipred2  25909  0.787711   0.836997
# 0               Affipred2                Affipred  25909  0.787711   0.836997
# 0     rhapsody_two_states                Affipred   7888  0.813904   0.874715
# 0                     all     rhapsody_two_states   7888  0.814205   0.857989
#
#      recall  accuracy  matthews_corr               confusion_matrix
# 0  0.915768  0.744686       0.544097    [[9637, 5606], [844, 9176]]
# 0  0.745309  0.841072       0.664455  [[13780, 1463], [2552, 7468]]
# 0  0.862420  0.775663       0.568748  [[10914, 4289], [1393, 8732]]
# 0  0.746765  0.841045       0.665488  [[13741, 1462], [2564, 7561]]
# 0  0.916533  0.715632       0.503619    [[8643, 6068], [783, 8598]]
# 0  0.729133  0.835547       0.649774  [[13290, 1421], [2541, 6840]]
# 0  0.878904  0.772580       0.569797  [[10368, 4343], [1136, 8245]]
# 0  0.729133  0.835547       0.649774  [[13290, 1421], [2541, 6840]]
# 0  0.900574  0.752171       0.546796    [[8673, 4715], [936, 8478]]
# 0  0.750690  0.838172       0.663669  [[12045, 1343], [2347, 7067]]
# 0  0.974246  0.643707       0.446753    [[6759, 8646], [246, 9306]]
# 0  0.741834  0.842088       0.661511  [[13930, 1475], [2466, 7086]]
# 0  0.853969  0.762450       0.544233  [[10204, 4265], [1321, 7725]]
# 0  0.724077  0.836785       0.650468  [[13127, 1342], [2496, 6550]]
# 0  0.740796  0.729811       0.455082  [[10928, 4197], [2605, 7445]]
# 0  0.745970  0.840556       0.664256  [[13664, 1461], [2553, 7497]]
# 0  0.869213  0.811445       0.629328  [[11832, 3469], [1322, 8786]]
# 0  0.745647  0.840962       0.664635  [[13831, 1470], [2571, 7537]]
# 0  0.832784  0.853888       0.697290  [[13452, 2047], [1724, 8586]]
# 0  0.744520  0.840366       0.663932  [[14013, 1486], [2634, 7676]]
# 0  0.830650  0.832423       0.656836  [[12920, 2579], [1746, 8564]]
# 0  0.744520  0.840366       0.663932  [[14013, 1486], [2634, 7676]]
# 0  0.950847  0.949465       0.895399    [[14748, 800], [508, 9827]]
# 0  0.744267  0.840436       0.664018  [[14061, 1487], [2643, 7692]]
# 0  0.981275  0.705833       0.468428   [[3438, 5455], [193, 10114]]
# 0  0.744834  0.813542       0.639569    [[7943, 950], [2630, 7677]]
# 0  0.419790  0.730552       0.427285  [[14291, 1015], [5805, 4200]]
# 0  0.742729  0.841413       0.664678  [[13866, 1440], [2574, 7431]]
# 0  0.807648  0.840583       0.665680  [[12955, 2086], [1821, 7646]]
# 0  0.728319  0.836788       0.651196  [[13613, 1428], [2572, 6895]]
# 0  0.930106  0.933983       0.863184    [[14542, 985], [722, 9608]]
# 0  0.744337  0.840353       0.663914  [[14040, 1487], [2641, 7689]]
# 0  0.920426  0.882082       0.764407   [[13300, 2227], [822, 9508]]
# 0  0.744337  0.840353       0.663914  [[14040, 1487], [2641, 7689]]
# 0  0.972357  0.946375       0.891569  [[14400, 1099], [285, 10025]]
# 0  0.744520  0.840366       0.663932  [[14013, 1486], [2634, 7676]]
# 0  0.892501  0.752305       0.544154   [[9735, 5074], [1078, 8950]]
# 0  0.744416  0.840399       0.665468  [[13408, 1401], [2563, 7465]]
# 0  0.976864  0.642882       0.442896   [[6532, 8995], [239, 10091]]
# 0  0.744337  0.840353       0.663914  [[14040, 1487], [2641, 7689]]
# 0  0.910464  0.772336       0.582596    [[9998, 4617], [836, 8501]]
# 0  0.746385  0.841976       0.664002  [[13198, 1417], [2368, 6969]]
# 0  0.848167  0.824306       0.603775     [[2094, 620], [911, 5089]]
# 0  0.799833  0.809272       0.596415    [[2253, 461], [1201, 4799]]
# 0  0.918956  0.725308       0.517511    [[9290, 6279], [838, 9502]]
# 0  0.743907  0.839978       0.662972  [[14071, 1498], [2648, 7692]]
# 0  0.743907  0.839978       0.662972  [[14071, 1498], [2648, 7692]]
# 0  0.743907  0.839978       0.662972  [[14071, 1498], [2648, 7692]]
# 0  0.743907  0.839978       0.662972  [[14071, 1498], [2648, 7692]]
# 0  0.760999  0.777383       0.548389    [[2292, 550], [1206, 3840]]
# 0  0.774673  0.773834       0.531669    [[2195, 647], [1137, 3909]]

# %%
df = dfx2

preds =  ['SIFT_pred','SIFT4G_pred',"PolyPhen-2_two_states",'Polyphen2_HDIV_pred', 'Polyphen2_HVAR_pred','LRT_pred',
          'MutationTaster_pred', 'MutationAssessor_pred', 'FATHMM_pred',  'PROVEAN_pred',  'MetaSVM_pred','MetaLR_pred', 
          'MetaRNN_pred', 'PrimateAI_pred','DEOGEN2_pred','BayesDel_addAF_pred','BayesDel_noAF_pred',
          'ClinPred_pred','LIST-S2_pred', 'fathmm-MKL_coding_pred', 'fathmm-XF_coding_pred', 'M-CAP_pred', "EVmutation_two_states",
          'rhapsody_two_states']
# print(len(preds))

fig,ax = plt.subplots(1,24, figsize=(24,5),sharex=True,sharey=True)
plt.ylim(0,0.9)

for i, p in enumerate(preds):
    dx = df.loc[(df["predictor"]==p)|(df["dataset"]==p)]
    dx=dx.sort_values("predictor")
    sns.barplot(ax = ax[i],data=dx,y ="f1", x="predictor",palette=["lightgreen","lightgrey"])
    p = p.replace('_pred', '') 
    p = p.replace('_two_states', '') 
    p = p.replace('_coding', '') 
    ax[i].set_title("affipred\n"+str(p),rotation=90,fontsize=20,loc='left',x=0.1, y=0.01)
    ax[i].set_ylabel("",rotation=90,fontsize=20)
    ax[0].set_ylabel("F1",rotation=90,fontsize=20)
    ax[i].set_xlabel("",rotation=90,fontsize=20)
    ax[i].tick_params(labelsize=20)
    ax[i].spines['top'].set_visible(False)
    ax[i].spines['right'].set_visible(False)
    ax[i].spines['bottom'].set_visible(True)
    ax[i].spines['left'].set_visible(False)  
    ax[0].spines['left'].set_visible(True)
    ax[23].spines['right'].set_visible(True) 
    ax[i].set_xticks([])
    ax[i].set_yticks([0,0.5,1.0])
        
plt.savefig(str(savename)+"_blind_f1.png", dpi=300, facecolor='w', bbox_inches='tight', pad_inches=0.01)    
    
plt.show()

fig,ax = plt.subplots(1,24, figsize=(24,5),sharex=True,sharey=True)
plt.ylim(0,0.9)

for i, p in enumerate(preds):
    dx = df.loc[(df["predictor"]==p)|(df["dataset"]==p)]
    dx=dx.sort_values("predictor")
    sns.barplot(ax = ax[i],data=dx,y ="matthews_corr", x="predictor",palette=["navajowhite","lightgrey"])
    p = p.replace('_pred', '') 
    p = p.replace('_two_states', '') 
    p = p.replace('_coding', '') 
    ax[i].set_title("affipred\n"+str(p),rotation=90,fontsize=20,loc='left',x=0.1, y=0.01)
    ax[i].set_ylabel("",rotation=90,fontsize=20)
    ax[0].set_ylabel("MCC",rotation=90,fontsize=20)
    ax[i].set_xlabel("",rotation=90,fontsize=20)
    ax[i].tick_params(labelsize=20)
    ax[i].spines['top'].set_visible(False)
    ax[i].spines['right'].set_visible(False)
    ax[i].spines['bottom'].set_visible(True)
    ax[i].spines['left'].set_visible(False)
    ax[0].spines['left'].set_visible(True)
    ax[23].spines['right'].set_visible(True)
    ax[i].set_xticks([])
    ax[i].set_yticks([0,0.5,1.0])
        
plt.savefig(str(savename)+"_blind_mcc.png", dpi=300, facecolor='w', bbox_inches='tight', pad_inches=0.01)    

plt.show()

s = []
for i, p in enumerate(preds):
    dx = df.loc[(df["predictor"]==p)|(df["dataset"]==p)]
    dx=dx.sort_values("predictor")
    s.append(dx["size"])
# print(s)
fig,ax = plt.subplots(1,1, figsize=(23,3),sharex=True,sharey=True)
plt.ylim(0,28000)
plt.xlim(-0.5,23.5)
plt.plot(s,color="red",marker=".",markersize=20)
plt.tick_params(labelsize=20)
plt.yticks([0,14000,28000],["0","14K","28K"])
plt.xticks([])
plt.ylabel("size",rotation=90,fontsize=20)
        
plt.savefig(str(savename)+"_blind_size.png", dpi=300, facecolor='w', bbox_inches='tight', pad_inches=0.01)    

plt.show()

# %%
df1 = blind
df1['EVmutation_score']=1-df1['EVmutation_score']
predscores = ['SIFT_converted_rankscore', 'SIFT4G_converted_rankscore','Polyphen2_HDIV_rankscore', 'Polyphen2_HVAR_rankscore', 
           'LRT_converted_rankscore', 'MutationTaster_converted_rankscore', 'MutationAssessor_rankscore', 'FATHMM_converted_rankscore', 
           'PROVEAN_converted_rankscore', 'VEST4_rankscore','MetaSVM_rankscore','MetaLR_rankscore', 'MetaRNN_rankscore', 
           'M-CAP_rankscore','REVEL_rankscore','MutPred_rankscore', 'MVP_rankscore','MPC_rankscore', 'PrimateAI_rankscore', 
            'DEOGEN2_rankscore','BayesDel_addAF_rankscore','BayesDel_noAF_rankscore', 'ClinPred_rankscore', 'LIST-S2_rankscore', 
           'CADD_raw_rankscore', 'DANN_rankscore', 'fathmm-MKL_coding_rankscore','fathmm-XF_coding_rankscore', 'Eigen-raw_coding_rankscore', 
            'Eigen-PC-raw_coding_rankscore', 'GenoCanyon_rankscore', 'integrated_fitCons_rankscore', 'GERP++_RS_rankscore', 
            'phyloP100way_vertebrate_rankscore', 'phyloP30way_mammalian_rankscore','phastCons100way_vertebrate_rankscore', 
            'phastCons30way_mammalian_rankscore', 'SiPhy_29way_logOdds_rankscore','rhapsody_prob.', 'EVmutation_score', 'PolyPhen-2_score']

ls = ["two_states","Affipred_prob2"]
predscores = ls + predscores
# print(predscores)
# predscores = [i for i in predscores if "_score" not in i]
df1 = blind
df2 = df1.loc[df1["training_info"]=="new"]

### Evaluate on all of the unseen test set
df = df1[predscores]
predscores = [i for i in predscores if "two_states" not in i ]

prednames = []
for p in predscores:
    head, sep, tail = p.partition('_r')
    head, sep, tail = head.partition('_co')
    head, sep, tail = head.partition('_prob')
    prednames.append(head)

colors = []
for i in range(len(predscores)-1):
    color = plt.cm.seismic(np.linspace(0, 1, len(predscores)-1))
    colors.append(color)

rocvals = []
for i, p in enumerate(predscores):
    # print(p)
    color = plt.cm.rainbow(np.linspace(0, 1, len(predscores)))

    dx = df.loc[~df[p].isna()]
    fpr, tpr, thres = metrics.roc_curve(dx["two_states"], dx[p])
    dr = {"name":p,"fpr":fpr,"tpr":tpr,"scores":thres}
    dr = pd.DataFrame(dr)

    if prednames[i] == "Affipred":
        plt.figure(figsize=(10,10))
        plt.plot(fpr,tpr,label=prednames[i],color="black",linewidth=4)
    else:

        plt.plot(fpr,tpr,label=prednames[i],color=color[i],linewidth=2,linestyle="-")
        plt.plot([0,0.5,1],[0,0.5,1],color ="grey",linestyle="-",linewidth=0.5)
        plt.ylabel('True Positive Fraction',fontsize=25)
        plt.xlabel('False Positive Fraction',fontsize=25)
        plt.tick_params(axis='both', which='both', labelsize=25)
        plt.legend(loc =(1,0),ncol= 2,frameon=False,fontsize=20)
        plt.title("Blind test set (n="+str(len(df1))+")",fontsize=25,x=0.5, y=1.0)
os.chdir(path2res)
plt.savefig(str(savename) +'_ROCblindtest.png', facecolor='w', bbox_inches='tight', pad_inches=0.01)

plt.show()

# %% [markdown]
# ### DB Prediction

# %%
aa_list = ["A","C","D","E","F","G","H","I","K","L","M","N","P","Q","R","S","T","V","W","Y"]
for aa in aa_list:
    os.chdir('D:\\__PROJECTS\\__AFbPP\\April2023\\affipred_models\\DB\\')
    df = pd.read_csv("DB_10feat_AFbPP_fold1_evals"+str(evals)+"_mutant_"+str(aa)+".csv",sep=";")

    X = df[features]
    y_pred = xgbs.predict(X)
    y_prob = xgbs.predict_proba(X)[:,1]
    df["Affipred"+str(NUMBER)] = y_pred
    df["Affipred_prob"+str(NUMBER)] = y_prob
    df.to_csv("DB_10feat_AFbPP_fold1"+str(NUMBER)+"_evals"+str(evals)+"_mutant_"+str(aa)+".csv",sep=";")
    print(aa)
    os.remove("DB_10feat_AFbPP_fold1_evals"+str(evals)+"_mutant_"+str(aa)+".csv")
# Out:
# A
# C
# D
# E
# F
# G
# H
# I
# K
# L
# M
# N
# P
# Q
# R
# S
# T
# V
# W
# Y
